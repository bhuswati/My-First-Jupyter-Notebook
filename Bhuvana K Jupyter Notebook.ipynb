# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Bhuvana K**<br>
# Pursuing courses to become a Data Scientist

# %% [markdown]
# *My interest in Data Science started when I explored new opportunities in SAS based jobs. <br> Accidentally, I came across various requirements expected by the hiring companies and introduced to Python, R, Bigdata and eventually Data science. <br> Ever since I am nurturing the inner sense to explore more and more in Data science and I believe I will become a Data Scientist in the coming years.*

# %% [markdown]
# ### Let us do a simple mathematical multiplication to generate a magical number

# %%
1111111*1111111
# Out:
# 1234567654321

# %% [markdown]
# > It is fun learning data science. <br>
# >
#
# **I recommend everyone who is curious about Data Science to learn from Coursera! Enroll Today !** [CLick here to Login](https://in.coursera.org/)
#
# What do get out of learning Data Science?
# * Fun!
# * Fun!
# * Fun!
#
# #### Here is the list of some of the commonly used Data Science Tools
#
# |  Tools  |  Uses  |
# |  ---  |  ---|
# |IBM Watson Studio |Multi-purpose - Data Integration, Governance, Model building and Deployment|
